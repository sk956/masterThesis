# %%
# checking again the code at this time 
import pandas as pd

# %%
 pwd = "/Users/rentaluser/Desktop/masterThesis/emotionCSV"

# %%
csvPath = pwd + "/testingvideo.csv"

# %%
csvPath
# Out:
# '/Users/rentaluser/Desktop/masterThesis/emotionCSV/testingvideo.csv'

# %%
df = pd.read_csv(csvPath)

# %%
# find the P1 identified person data  / find the p2 idnetified dataset / find the p3 identified dataset 

p1 = df.loc[df['identified_person'] == "P1"] 
p2 = df.loc[df['identified_person'] == "P2"] 
p3 = df.loc[df['identified_person'] == "P3"] 

# indexing to help with data analysis in R section.

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 2            3  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 5            6  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 8            9  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 10          11  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 14          15  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 16          17  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 19          20  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 21          22  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 26          27  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 28          29  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 30          31  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 34          35  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 36          37  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 40          41  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 44          45  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 45          46  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 49          50  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 53          54  /Users/rentaluser/Desktop/thesisVideo/videoFac...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 2               0                P1                  99.996201        3
# 5               0                P1                  99.996201        3
# 8              17                P1                  99.998299        3
# 10             37                P1                  99.997803        2
# 14             57                P1                  99.997803        3
# 16             77                P1                  99.996201        2
# 19             97                P1                  99.997803        2
# 21            117                P1                  99.996201        1
# 26            137                P1                  99.997803        3
# 28            157                P1                  99.998299        2
# 30            177                P1                  99.997803        1
# 34            197                P1                  99.997803        2
# 36            217                P1                  99.997803        1
# 40            237                P1                  99.997803        2
# 44            257                P1                  99.997803        3
# 45            277                P1                  99.998299        1
# 49            297                P1                  99.996201        2
# 53            317                P1                  99.996201        3
#
#     age_low  age_high  smile  eyeglasses  ...  eyesopen mouthopen   confused  \
# 2        22        34   True        True  ...      True      True   0.230567
# 5        22        34   True        True  ...      True      True   0.199444
# 8        21        33  False        True  ...      True     False   4.642385
# 10       19        31  False        True  ...      True      True   1.575729
# 14       18        30  False        True  ...      True     False  17.890076
# 16       22        34   True        True  ...      True      True   0.100431
# 19       22        34   True        True  ...      True      True   0.201734
# 21       18        30  False        True  ...      True     False  17.339701
# 26       21        33  False        True  ...      True      True   1.403091
# 28       21        33  False        True  ...      True     False   0.644233
# 30       22        34   True        True  ...      True      True   3.973478
# 34       21        33   True        True  ...      True      True   0.241393
# 36       20        32  False        True  ...      True     False  10.613461
# 40       22        34  False        True  ...      True     False   8.494196
# 44       22        34   True        True  ...      True      True   0.383512
# 45       19        31  False        True  ...      True     False  18.923012
# 49       18        30  False        True  ...      True     False   9.783781
# 53       13        25  False        True  ...      True     False   1.266816
#
#          calm      happy  disgusted     angry      fear        sad  surprised
# 2    0.028590  96.722588   2.313241  0.279859  0.099994   0.158332   0.166830
# 5    0.023717  97.399841   1.782167  0.234159  0.079187   0.136344   0.145146
# 8   45.383293   1.905782   1.594645  0.470597  0.486016   0.580621  44.936665
# 10   1.437323   2.107808  74.172150  7.121443  2.374945   0.156850  11.053752
# 14  52.879066   5.538433   9.098866  1.838339  0.549393   9.068830   3.136998
# 16   0.013623  98.970543   0.416200  0.101933  0.053882   0.021670   0.321720
# 19   0.119973  93.117973   5.110552  0.293849  0.177705   0.201693   0.776513
# 21  73.856964   0.774260   1.701652  1.380582  0.361168   2.082826   2.502850
# 26   8.617386   1.867988   1.070327  0.382143  1.425203   1.624813  83.609055
# 28  16.883398   0.282951   0.841471  0.534663  1.429194  78.959267   0.424824
# 30  18.745371  33.551647   7.012605  1.035520  0.227879   0.413477  35.040028
# 34   0.066358  96.447792   1.608413  0.134772  0.142082   0.103926   1.255256
# 36  84.915092   0.685625   0.542141  0.585050  0.088737   1.154633   1.415268
# 40  70.168777   7.329979   6.351211  1.136232  0.327464   1.755196   4.436956
# 44   0.086563  94.180855   2.980929  0.158804  0.116483   0.109320   1.983539
# 45  51.565571   2.067178   2.182302  0.747683  0.247014   1.295033  22.972210
# 49  67.258591   0.585253   2.830164  0.827460  0.335143   0.755261  17.624342
# 53   3.386174   0.078355   0.331860  0.064884  0.087326   0.044631  94.739952
#
# [18 rows x 24 columns]

# %%
def emotions_col(pd) :
    pd['emotions'] =  (-1) *pd['confused'] + pd['calm'] + pd['happy'] - pd['disgusted'] + pd['angry'] - pd['fear'] + pd['sad'] + pd['surprised'] 
    return pd

# %%
p1 = emotions_col(p1)
p2 = emotions_col(p2) 
p3 = emotions_col(p3) 

# change the indexing
# Out:
# <ipython-input-27-f722d05ca7ec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd['emotions'] =  (-1) *pd['confused'] + pd['calm'] + pd['happy'] - pd['disgusted'] + pd['angry'] - pd['fear'] + pd['sad'] + pd['surprised']
#     Unnamed: 0                                           frame_id  \
# 0            1  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 3            4  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 6            7  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 9           10  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 12          13  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 15          16  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 18          19  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 23          24  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 24          25  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 29          30  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 32          33  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 33          34  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 39          40  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 42          43  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 46          47  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 48          49  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 51          52  /Users/rentaluser/Desktop/thesisVideo/videoFac...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0               0                P3                  99.997398        1
# 3               0                P3                  99.997398        1
# 6              17                P3                  99.997398        1
# 9              37                P3                  99.997398        1
# 12             57                P3                  99.997398        1
# 15             77                P3                  99.997398        1
# 18             97                P3                  99.996399        1
# 23            117                P3                  99.997398        3
# 24            137                P3                  99.996399        1
# 29            157                P3                  99.997398        3
# 32            177                P3                  99.997398        3
# 33            197                P3                  99.997398        1
# 39            237                P3                  99.997398        1
# 42            257                P3                  99.997398        1
# 46            277                P3                  99.935799        2
# 48            297                P3                  99.994698        1
# 51            317                P3                  99.997398        1
#
#     age_low  age_high  smile  eyeglasses  ...  mouthopen   confused  \
# 0        24        38  False       False  ...      False   0.398309
# 3        24        38  False       False  ...      False   0.469564
# 6        27        43  False       False  ...      False   0.640654
# 9        23        37  False       False  ...      False   1.414841
# 12       22        34  False       False  ...      False   0.373241
# 15       25        39  False       False  ...      False   5.422382
# 18       22        34   True       False  ...       True   0.214843
# 23       19        31   True       False  ...       True   2.138021
# 24       25        39  False       False  ...      False   7.649729
# 29       42        60  False       False  ...      False   1.449795
# 32       22        34  False       False  ...      False  14.637704
# 33       30        46   True       False  ...       True   0.324577
# 39       23        35  False       False  ...       True  45.114891
# 42       21        33  False       False  ...      False   0.377275
# 46       18        30  False       False  ...      False   0.773306
# 48       23        37  False       False  ...      False   0.813534
# 51       23        35  False       False  ...      False   1.678570
#
#          calm      happy  disgusted      angry       fear        sad  \
# 0   96.851044   0.179916   0.361110   1.154398   0.068499   0.896643
# 3   96.489037   0.183005   0.393107   1.288997   0.074294   0.999878
# 6   96.686951   0.228050   0.757354   0.286642   0.088113   1.198123
# 9   92.677185   0.407008   1.823785   1.284331   0.201153   2.045685
# 12  91.150215   0.563700   0.537311   4.532287   1.131705   1.255553
# 15  16.018848  56.005955   2.478889   3.011339   1.085485  14.512509
# 18   0.042883  99.083885   0.096579   0.074397   0.064246   0.037125
# 23   9.072857  82.388611   0.760767   3.579299   0.253856   0.903376
# 24  74.202477   5.663748   1.248875   1.667086   0.771021   2.917587
# 29   2.976840   0.831445   0.246112   1.068946  19.820362  73.411407
# 32  59.864990   1.178272   6.246240   5.152102   1.425050   8.966392
# 33   0.199833  98.018684   0.177885   0.524104   0.245156   0.148234
# 39   4.334858  19.126823   0.761607   1.361655   1.384794   0.656917
# 42  90.213547   6.948104   0.835762   0.642373   0.246183   0.458113
# 46  28.043980   1.619863   1.457876  12.245193  13.799678  40.677895
# 48  96.288658   0.309492   0.294513   0.696437   0.201170   1.165001
# 51  94.203255   0.149738   0.178263   2.137255   0.127962   1.354495
#
#     surprised   emotions
# 0    0.090084  98.344166
# 3    0.102115  98.126066
# 6    0.114111  97.027755
# 9    0.146004  93.120434
# 12   0.455996  95.915495
# 15   1.464586  82.026482
# 18   0.386050  99.248672
# 23   0.903212  93.694710
# 24   5.879482  80.660755
# 29   0.195089  56.967458
# 32   2.529244  55.382005
# 33   0.361530  98.504769
# 39  27.258459   5.477420
# 42   0.278643  97.081560
# 46   1.382211  67.938281
# 48   0.231191  97.381563
# 51   0.170457  96.030404
#
# [17 rows x 25 columns]

# %%
# 3 different csv files for the creations at this point 
postProcessing = "/Users/rentaluser/Desktop/masterThesis/emotionCSV/processed/testing"

p1.to_csv(postProcessing + "/p1.csv") 
p2.to_csv(postProcessing + "/p2.csv") 
p3.to_csv(postProcessing + "/p3.csv")
