# %%
# checking again the code at this time 
import pandas as pd

# %%
 pwd = "/Users/rentaluser/Desktop/masterThesis/emotionCSV"

# %%
csvPath = pwd + "/testingvideo.csv"

# %%
csvPath
# Out:
# '/Users/rentaluser/Desktop/masterThesis/emotionCSV/testingvideo.csv'

# %%
df = pd.read_csv(csvPath)

# %%
# find the P1 identified person data  / find the p2 idnetified dataset / find the p3 identified dataset 

p1 = df.loc[df['identified_person'] == "P1"] 
p2 = df.loc[df['identified_person'] == "P2"] 
p3 = df.loc[df['identified_person'] == "P3"] 

# indexing to help with data analysis in R section.
p1.index =range(len(p1['identified_person']))
p2.index =range(len(p2['identified_person']))
p3.index =range(len(p3['identified_person']))

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            3  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 1            6  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 2            9  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 3           11  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 4           15  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 5           17  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 6           20  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 7           22  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 8           27  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 9           29  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 10          31  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 11          35  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 12          37  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 13          41  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 14          45  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 15          46  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 16          50  /Users/rentaluser/Desktop/thesisVideo/videoFac...
# 17          54  /Users/rentaluser/Desktop/thesisVideo/videoFac...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0               0                P1                  99.996201        3
# 1               0                P1                  99.996201        3
# 2              17                P1                  99.998299        3
# 3              37                P1                  99.997803        2
# 4              57                P1                  99.997803        3
# 5              77                P1                  99.996201        2
# 6              97                P1                  99.997803        2
# 7             117                P1                  99.996201        1
# 8             137                P1                  99.997803        3
# 9             157                P1                  99.998299        2
# 10            177                P1                  99.997803        1
# 11            197                P1                  99.997803        2
# 12            217                P1                  99.997803        1
# 13            237                P1                  99.997803        2
# 14            257                P1                  99.997803        3
# 15            277                P1                  99.998299        1
# 16            297                P1                  99.996201        2
# 17            317                P1                  99.996201        3
#
#     age_low  age_high  smile  eyeglasses  ...  eyesopen mouthopen   confused  \
# 0        22        34   True        True  ...      True      True   0.230567
# 1        22        34   True        True  ...      True      True   0.199444
# 2        21        33  False        True  ...      True     False   4.642385
# 3        19        31  False        True  ...      True      True   1.575729
# 4        18        30  False        True  ...      True     False  17.890076
# 5        22        34   True        True  ...      True      True   0.100431
# 6        22        34   True        True  ...      True      True   0.201734
# 7        18        30  False        True  ...      True     False  17.339701
# 8        21        33  False        True  ...      True      True   1.403091
# 9        21        33  False        True  ...      True     False   0.644233
# 10       22        34   True        True  ...      True      True   3.973478
# 11       21        33   True        True  ...      True      True   0.241393
# 12       20        32  False        True  ...      True     False  10.613461
# 13       22        34  False        True  ...      True     False   8.494196
# 14       22        34   True        True  ...      True      True   0.383512
# 15       19        31  False        True  ...      True     False  18.923012
# 16       18        30  False        True  ...      True     False   9.783781
# 17       13        25  False        True  ...      True     False   1.266816
#
#          calm      happy  disgusted     angry      fear        sad  surprised
# 0    0.028590  96.722588   2.313241  0.279859  0.099994   0.158332   0.166830
# 1    0.023717  97.399841   1.782167  0.234159  0.079187   0.136344   0.145146
# 2   45.383293   1.905782   1.594645  0.470597  0.486016   0.580621  44.936665
# 3    1.437323   2.107808  74.172150  7.121443  2.374945   0.156850  11.053752
# 4   52.879066   5.538433   9.098866  1.838339  0.549393   9.068830   3.136998
# 5    0.013623  98.970543   0.416200  0.101933  0.053882   0.021670   0.321720
# 6    0.119973  93.117973   5.110552  0.293849  0.177705   0.201693   0.776513
# 7   73.856964   0.774260   1.701652  1.380582  0.361168   2.082826   2.502850
# 8    8.617386   1.867988   1.070327  0.382143  1.425203   1.624813  83.609055
# 9   16.883398   0.282951   0.841471  0.534663  1.429194  78.959267   0.424824
# 10  18.745371  33.551647   7.012605  1.035520  0.227879   0.413477  35.040028
# 11   0.066358  96.447792   1.608413  0.134772  0.142082   0.103926   1.255256
# 12  84.915092   0.685625   0.542141  0.585050  0.088737   1.154633   1.415268
# 13  70.168777   7.329979   6.351211  1.136232  0.327464   1.755196   4.436956
# 14   0.086563  94.180855   2.980929  0.158804  0.116483   0.109320   1.983539
# 15  51.565571   2.067178   2.182302  0.747683  0.247014   1.295033  22.972210
# 16  67.258591   0.585253   2.830164  0.827460  0.335143   0.755261  17.624342
# 17   3.386174   0.078355   0.331860  0.064884  0.087326   0.044631  94.739952
#
# [18 rows x 24 columns]

# %%
def emotions_col(pd) :
    pd['emotions'] =  (-1) *pd['confused'] + pd['calm'] + pd['happy'] - pd['disgusted'] + pd['angry'] - pd['fear'] + pd['sad'] + pd['surprised'] 
    return pd

# %%
""" Create a column that changes from ms to minutes  -> easier to look / view at the line graphs plot"""
def secs_to_min(pd): 
    pd['min_timestamp'] = pd['img_timestamp']/60 
    return pd

# %%
p1 = emotions_col(p1)
p1 = secs_to_min(p1)
p2 = emotions_col(p2)
p2 = secs_to_min(p2)
p3 = emotions_col(p3)
p3= secs_to_min(p3)

# change the indexing
# Out:
# <ipython-input-34-f722d05ca7ec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd['emotions'] =  (-1) *pd['confused'] + pd['calm'] + pd['happy'] - pd['disgusted'] + pd['angry'] - pd['fear'] + pd['sad'] + pd['surprised']
# <ipython-input-38-a5b7c8120103>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd['min_timestamp'] = pd['img_timestamp']/60

# %%
# 3 different csv files for the creations at this point 
postProcessing = "/Users/rentaluser/Desktop/masterThesis/emotionCSV/processed/testing"

p1.to_csv(postProcessing + "/p1.csv") 
p2.to_csv(postProcessing + "/p2.csv") 
p3.to_csv(postProcessing + "/p3.csv")
