# %%
# checking again the code at this time 
import pandas as pd

# %%
 pwd = "/Users/rentaluser/Desktop/masterThesis/emotionCSV/rawcsv/"

# %%
csvPath = pwd + "/pilotteam1round3.csv"

# %%
csvPath
# Out:
# '/Users/rentaluser/Desktop/masterThesis/emotionCSV/rawcsv//pilotteam1round3.csv'

# %%
df = pd.read_csv(csvPath)

# %%
# find the P1 identified person data  / find the p2 idnetified dataset / find the p3 identified dataset 

p1 = df.loc[df['identified_person'] == "P1"] 
p2 = df.loc[df['identified_person'] == "P2"] 
p3 = df.loc[df['identified_person'] == "P3"] 

# indexing to help with data analysis in R section.
p1.index =range(len(p1['identified_person']))
p2.index =range(len(p2['identified_person']))
p3.index =range(len(p3['identified_person']))

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            3  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            7  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2           10  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           14  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           17  //Users/rentaluser/desktop/thesisVideo/videos/...
# ..         ...                                                ...
# 91         275  //Users/rentaluser/desktop/thesisVideo/videos/...
# 92         278  //Users/rentaluser/desktop/thesisVideo/videos/...
# 93         281  //Users/rentaluser/desktop/thesisVideo/videos/...
# 94         284  //Users/rentaluser/desktop/thesisVideo/videos/...
# 95         287  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0              17                P1                  99.997803        1
# 1              37                P1                  99.997803        2
# 2              57                P1                  99.998299        2
# 3              77                P1                  99.997803        3
# 4              97                P1                  99.998299        3
# ..            ...               ...                        ...      ...
# 91           1837                P1                  99.998299        3
# 92           1857                P1                  99.997803        3
# 93           1877                P1                  99.998299        3
# 94           1897                P1                  99.997803        3
# 95           1917                P1                  99.998299        3
#
#     age_low  age_high  smile  eyeglasses  ...  eyesopen mouthopen   confused  \
# 0        22        34   True        True  ...      True      True   0.068990
# 1        18        30  False        True  ...      True     False   5.436790
# 2        22        34  False        True  ...      True     False  13.221715
# 3        22        34  False        True  ...      True     False   5.995524
# 4        18        30  False        True  ...      True     False   9.272771
# ..      ...       ...    ...         ...  ...       ...       ...        ...
# 91       16        28  False        True  ...      True     False  18.236954
# 92       19        31  False        True  ...      True     False  11.864931
# 93       21        33  False        True  ...      True     False  20.131721
# 94       14        26  False        True  ...      True     False  15.406474
# 95       22        34  False        True  ...      True     False   2.684721
#
#          calm      happy  disgusted     angry       fear        sad  surprised
# 0    0.021385  99.385010   0.264424  0.108056   0.046274   0.036204   0.069659
# 1   79.486984   2.214420   2.597090  0.969500   0.981134   1.913680   6.400394
# 2   70.649529   3.554184   1.739287  1.156059   0.825131   4.183560   4.670530
# 3    6.809622   0.265254   2.036910  0.357872  58.271511  23.785713   2.477599
# 4   81.051399   1.232381   1.584563  0.929156   0.349222   3.027021   2.553485
# ..        ...        ...        ...       ...        ...        ...        ...
# 91  64.347160   1.214478   3.693368  1.397466   0.392871   8.919059   1.798640
# 92  47.793240   1.782918   3.355094  2.889596   0.285243  30.797152   1.231832
# 93  62.337852   2.776122   2.767076  1.276263   0.386404   7.617859   2.706701
# 94  49.012138   1.364167   3.035949  4.316742   0.283255  25.420364   1.160913
# 95   8.776689   2.214968  29.569695  0.983648   0.452715  55.096413   0.221158
#
# [96 rows x 24 columns]

# %%
# delete all the rows where the imgTimestamp is 0 

def delete_all_zero(pd): 
    list_drop = []
    for i in range(len(pd['img_timestamp'])): 
        if pd.iloc[i]['img_timestamp'] == 0:    
            list_drop.append(i)
    
    # delete the indexes 
    pd  = pd.drop(list_drop)
    return pd

# %%
p1 = delete_all_zero(p1)
p2 =  delete_all_zero(p2)
p3 = delete_all_zero(p3)

p1.index =range(len(p1['identified_person']))
p2.index =range(len(p2['identified_person']))
p3.index =range(len(p3['identified_person']))

# %%
p3
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            4  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            6  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2            9  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           12  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           15  //Users/rentaluser/desktop/thesisVideo/videos/...
# ..         ...                                                ...
# 85         273  //Users/rentaluser/desktop/thesisVideo/videos/...
# 86         276  //Users/rentaluser/desktop/thesisVideo/videos/...
# 87         279  //Users/rentaluser/desktop/thesisVideo/videos/...
# 88         282  //Users/rentaluser/desktop/thesisVideo/videos/...
# 89         285  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0              17                P3                  99.997398        2
# 1              37                P3                  99.997398        1
# 2              57                P3                  99.997398        1
# 3              77                P3                  99.997398        1
# 4              97                P3                  99.994698        1
# ..            ...               ...                        ...      ...
# 85           1837                P3                  99.997398        1
# 86           1857                P3                  99.997398        1
# 87           1877                P3                  99.997398        1
# 88           1897                P3                  99.997398        1
# 89           1917                P3                  99.997398        1
#
#     age_low  age_high  smile  eyeglasses  ...  eyesopen mouthopen   confused  \
# 0        21        33   True       False  ...      True     False   0.572538
# 1        21        33  False       False  ...      True     False   0.561842
# 2        22        34  False       False  ...      True     False   2.018306
# 3        22        34  False       False  ...      True     False   2.206092
# 4        26        42  False       False  ...      True      True   4.470227
# ..      ...       ...    ...         ...  ...       ...       ...        ...
# 85       22        34  False       False  ...      True     False  18.793013
# 86       26        42  False       False  ...      True     False  45.498119
# 87       23        37  False       False  ...      True     False  52.266701
# 88       23        35  False       False  ...      True     False  56.818436
# 89       25        39  False       False  ...      True     False  58.579369
#
#          calm      happy  disgusted     angry       fear        sad  surprised
# 0    0.599532  97.585617   0.161100  0.192006   0.264532   0.106838   0.517827
# 1   37.995777  59.075905   0.214424  0.271393   0.247683   0.934055   0.698925
# 2   89.659676   0.244485   0.227889  0.738702   0.728512   6.243715   0.138716
# 3   94.170349   0.150798   0.234983  0.501953   0.051176   2.583024   0.101632
# 4    0.610103   3.390328   7.090087  1.868888  80.385628   1.381763   0.802974
# ..        ...        ...        ...       ...        ...        ...        ...
# 85   9.102028   0.811602   1.708314  0.993030  53.855141  14.083969   0.652905
# 86  14.922221   0.856911   3.087002  1.077287   9.708982  24.086264   0.763216
# 87   6.537151   0.448972   2.712608  0.717530  31.181032   4.876932   1.259079
# 88   4.442235   0.513155   3.406068  0.801236  20.669281  12.479297   0.870295
# 89   4.507125   0.428984   1.086219  0.845596  29.549700   3.893260   1.109742
#
# [90 rows x 24 columns]

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            3  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            7  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2           10  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           14  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           17  //Users/rentaluser/desktop/thesisVideo/videos/...
# ..         ...                                                ...
# 91         275  //Users/rentaluser/desktop/thesisVideo/videos/...
# 92         278  //Users/rentaluser/desktop/thesisVideo/videos/...
# 93         281  //Users/rentaluser/desktop/thesisVideo/videos/...
# 94         284  //Users/rentaluser/desktop/thesisVideo/videos/...
# 95         287  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0              17                P1                  99.997803        1
# 1              37                P1                  99.997803        2
# 2              57                P1                  99.998299        2
# 3              77                P1                  99.997803        3
# 4              97                P1                  99.998299        3
# ..            ...               ...                        ...      ...
# 91           1837                P1                  99.998299        3
# 92           1857                P1                  99.997803        3
# 93           1877                P1                  99.998299        3
# 94           1897                P1                  99.997803        3
# 95           1917                P1                  99.998299        3
#
#     age_low  age_high  smile  eyeglasses  ...  eyesopen mouthopen   confused  \
# 0        22        34   True        True  ...      True      True   0.068990
# 1        18        30  False        True  ...      True     False   5.436790
# 2        22        34  False        True  ...      True     False  13.221715
# 3        22        34  False        True  ...      True     False   5.995524
# 4        18        30  False        True  ...      True     False   9.272771
# ..      ...       ...    ...         ...  ...       ...       ...        ...
# 91       16        28  False        True  ...      True     False  18.236954
# 92       19        31  False        True  ...      True     False  11.864931
# 93       21        33  False        True  ...      True     False  20.131721
# 94       14        26  False        True  ...      True     False  15.406474
# 95       22        34  False        True  ...      True     False   2.684721
#
#          calm      happy  disgusted     angry       fear        sad  surprised
# 0    0.021385  99.385010   0.264424  0.108056   0.046274   0.036204   0.069659
# 1   79.486984   2.214420   2.597090  0.969500   0.981134   1.913680   6.400394
# 2   70.649529   3.554184   1.739287  1.156059   0.825131   4.183560   4.670530
# 3    6.809622   0.265254   2.036910  0.357872  58.271511  23.785713   2.477599
# 4   81.051399   1.232381   1.584563  0.929156   0.349222   3.027021   2.553485
# ..        ...        ...        ...       ...        ...        ...        ...
# 91  64.347160   1.214478   3.693368  1.397466   0.392871   8.919059   1.798640
# 92  47.793240   1.782918   3.355094  2.889596   0.285243  30.797152   1.231832
# 93  62.337852   2.776122   2.767076  1.276263   0.386404   7.617859   2.706701
# 94  49.012138   1.364167   3.035949  4.316742   0.283255  25.420364   1.160913
# 95   8.776689   2.214968  29.569695  0.983648   0.452715  55.096413   0.221158
#
# [96 rows x 24 columns]

# %%
def emotions_col(pd) :
    pd['emotions'] =  (-1) *pd['confused'] + pd['calm'] + pd['happy'] - pd['disgusted'] + pd['angry'] - pd['fear'] + pd['sad'] + pd['surprised'] 
    
    return pd

# %%
# realized that the point graphs are cumulative 
def cum_emotions(pd): 
    pd['cum_emotions'] = 0.0
    for i in range(len(pd['emotions'])): 
        if i ==0 :
            pd.loc[i, 'cum_emotions'] = pd.iloc[i]['emotions']
        else: 
            pd.loc[i, 'cum_emotions'] = pd.iloc[i]['emotions'] +  pd.iloc[i-1]['cum_emotions']
        
    return pd

# %%
""" Create a column that changes from ms to minutes  -> easier to look / view at the line graphs plot"""
def secs_to_min(pd): 
    pd['min_timestamp'] = pd['img_timestamp']/60 
    # change it to like minutes / seconds 
    # minutes and seconds 
    return pd

# %%
""" seconds to minutes upgraded version to figureo out how to match the graph """
def secs_to_upMins(pd): 
    # minutes and seconds 
    pd['min_upgrade'] = 0.0
    for i in range(len(pd['img_timestamp'])): 
        
        mins = int(pd.iloc[i]['img_timestamp']/60) 
        secs = pd.iloc[i]['img_timestamp']%60
        newmins = mins + secs/100
        pd.loc[i,'min_upgrade'] = newmins
    return pd

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            3  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            7  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2           10  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           14  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           17  //Users/rentaluser/desktop/thesisVideo/videos/...
# ..         ...                                                ...
# 91         275  //Users/rentaluser/desktop/thesisVideo/videos/...
# 92         278  //Users/rentaluser/desktop/thesisVideo/videos/...
# 93         281  //Users/rentaluser/desktop/thesisVideo/videos/...
# 94         284  //Users/rentaluser/desktop/thesisVideo/videos/...
# 95         287  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0              17                P1                  99.997803        1
# 1              37                P1                  99.997803        2
# 2              57                P1                  99.998299        2
# 3              77                P1                  99.997803        3
# 4              97                P1                  99.998299        3
# ..            ...               ...                        ...      ...
# 91           1837                P1                  99.998299        3
# 92           1857                P1                  99.997803        3
# 93           1877                P1                  99.998299        3
# 94           1897                P1                  99.997803        3
# 95           1917                P1                  99.998299        3
#
#     age_low  age_high  smile  eyeglasses  ...  eyesopen mouthopen   confused  \
# 0        22        34   True        True  ...      True      True   0.068990
# 1        18        30  False        True  ...      True     False   5.436790
# 2        22        34  False        True  ...      True     False  13.221715
# 3        22        34  False        True  ...      True     False   5.995524
# 4        18        30  False        True  ...      True     False   9.272771
# ..      ...       ...    ...         ...  ...       ...       ...        ...
# 91       16        28  False        True  ...      True     False  18.236954
# 92       19        31  False        True  ...      True     False  11.864931
# 93       21        33  False        True  ...      True     False  20.131721
# 94       14        26  False        True  ...      True     False  15.406474
# 95       22        34  False        True  ...      True     False   2.684721
#
#          calm      happy  disgusted     angry       fear        sad  surprised
# 0    0.021385  99.385010   0.264424  0.108056   0.046274   0.036204   0.069659
# 1   79.486984   2.214420   2.597090  0.969500   0.981134   1.913680   6.400394
# 2   70.649529   3.554184   1.739287  1.156059   0.825131   4.183560   4.670530
# 3    6.809622   0.265254   2.036910  0.357872  58.271511  23.785713   2.477599
# 4   81.051399   1.232381   1.584563  0.929156   0.349222   3.027021   2.553485
# ..        ...        ...        ...       ...        ...        ...        ...
# 91  64.347160   1.214478   3.693368  1.397466   0.392871   8.919059   1.798640
# 92  47.793240   1.782918   3.355094  2.889596   0.285243  30.797152   1.231832
# 93  62.337852   2.776122   2.767076  1.276263   0.386404   7.617859   2.706701
# 94  49.012138   1.364167   3.035949  4.316742   0.283255  25.420364   1.160913
# 95   8.776689   2.214968  29.569695  0.983648   0.452715  55.096413   0.221158
#
# [96 rows x 24 columns]

# %%
""" main emotion and confidence level for each time line

calm	happy	disgusted	angry	fear	sad	surprised

""" 
def main_emotion(pd): 
    # main meotions 
    pd['main_emotion'] = 'emotion'
    pd['mainE_confidence'] = 0.0 
    for i in range(len(pd['img_timestamp'])): 
        # maximum of the values 
        max_e = max(pd.iloc[i]['calm'],pd.iloc[i]['happy'], pd.iloc[i]['disgusted'], pd.iloc[i]['angry'], 
                    pd.iloc[i]['fear'], pd.iloc[i]['sad'], pd.iloc[i]['surprised'])
        
        pd.loc[i, 'mainE_confidence'] = max_e
        
        if max_e == pd.iloc[i]['calm']: 
            pd.loc[i, 'main_emotion'] = 'calm' 
        
        if max_e == pd.iloc[i]['happy']: 
            pd.loc[i, 'main_emotion'] = 'happy' 
        if max_e == pd.iloc[i]['disgusted']: 
            pd.loc[i, 'main_emotion'] = 'disgusted' 
        if max_e == pd.iloc[i]['angry']: 
            pd.loc[i, 'main_emotion'] = 'angry' 
        if max_e == pd.iloc[i]['fear']: 
            pd.loc[i, 'main_emotion'] = 'fear' 
        if max_e == pd.iloc[i]['sad']: 
            pd.loc[i, 'main_emotion'] = 'sad' 
        if max_e == pd.iloc[i]['surprised']: 
            pd.loc[i, 'main_emotion'] = 'surprised'
        
    return pd

# %%
p1 = emotions_col(p1)
p1= cum_emotions(p1)
p1 = secs_to_min(p1)
p1 = secs_to_upMins(p1)
p1 = main_emotion(p1)

p2 = emotions_col(p2)
p2= cum_emotions(p2)
p2 = secs_to_min(p2)
p2 = secs_to_upMins(p2)
p2 = main_emotion(p2)

p3 = emotions_col(p3)
p3= cum_emotions(p3)
p3= secs_to_min(p3)
p3 = secs_to_upMins(p3)
p3 = main_emotion(p3)


# change the indexing

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            3  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            7  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2           10  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           14  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           17  //Users/rentaluser/desktop/thesisVideo/videos/...
# ..         ...                                                ...
# 91         275  //Users/rentaluser/desktop/thesisVideo/videos/...
# 92         278  //Users/rentaluser/desktop/thesisVideo/videos/...
# 93         281  //Users/rentaluser/desktop/thesisVideo/videos/...
# 94         284  //Users/rentaluser/desktop/thesisVideo/videos/...
# 95         287  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0              17                P1                  99.997803        1
# 1              37                P1                  99.997803        2
# 2              57                P1                  99.998299        2
# 3              77                P1                  99.997803        3
# 4              97                P1                  99.998299        3
# ..            ...               ...                        ...      ...
# 91           1837                P1                  99.998299        3
# 92           1857                P1                  99.997803        3
# 93           1877                P1                  99.998299        3
# 94           1897                P1                  99.997803        3
# 95           1917                P1                  99.998299        3
#
#     age_low  age_high  smile  eyeglasses  ...     angry       fear        sad  \
# 0        22        34   True        True  ...  0.108056   0.046274   0.036204
# 1        18        30  False        True  ...  0.969500   0.981134   1.913680
# 2        22        34  False        True  ...  1.156059   0.825131   4.183560
# 3        22        34  False        True  ...  0.357872  58.271511  23.785713
# 4        18        30  False        True  ...  0.929156   0.349222   3.027021
# ..      ...       ...    ...         ...  ...       ...        ...        ...
# 91       16        28  False        True  ...  1.397466   0.392871   8.919059
# 92       19        31  False        True  ...  2.889596   0.285243  30.797152
# 93       21        33  False        True  ...  1.276263   0.386404   7.617859
# 94       14        26  False        True  ...  4.316742   0.283255  25.420364
# 95       22        34  False        True  ...  0.983648   0.452715  55.096413
#
#     surprised   emotions  cum_emotions  min_timestamp  min_upgrade  \
# 0    0.069659  99.240625     99.240625       0.283333         0.17
# 1    6.400394  81.969965    181.210590       0.616667         0.37
# 2    4.670530  68.427729    249.638319       0.950000         0.57
# 3    2.477599 -32.607886    217.030433       1.283333         1.17
# 4    2.553485  77.586886    294.617320       1.616667         1.37
# ..        ...        ...           ...            ...          ...
# 91   1.798640  55.353610   6137.257782      30.616667        30.37
# 92   1.231832  68.989469   6206.247251      30.950000        30.57
# 93   2.706701  53.429598   6259.676848      31.283333        31.17
# 94   1.160913  62.548647   6322.225496      31.616667        31.37
# 95   0.221158  34.585745   6356.811240      31.950000        31.57
#
#     main_emotion  mainE_confidence
# 0          happy         99.385010
# 1           calm         79.486984
# 2           calm         70.649529
# 3           fear         58.271511
# 4           calm         81.051399
# ..           ...               ...
# 91          calm         64.347160
# 92          calm         47.793240
# 93          calm         62.337852
# 94          calm         49.012138
# 95           sad         55.096413
#
# [96 rows x 30 columns]

# %%
# 3 different csv files for the creations at this point 
postProcessing = "/Users/rentaluser/Desktop/masterThesis/emotionCSV/processed/pilot_study"

p1.to_csv(postProcessing + "/pilotteam1r3_Full_p1.csv") 
p2.to_csv(postProcessing + "/pilotteam1r3_Full_p2.csv") 
p3.to_csv(postProcessing + "/pilotteam1r3_Full_p3.csv")
