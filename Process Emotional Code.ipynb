# %%
# checking again the code at this time 
import pandas as pd

# %%
 pwd = "/Users/rentaluser/Desktop/masterThesis/emotionCSV"

# %%
csvPath = pwd + "/pilotteam1round2.csv"

# %%
csvPath
# Out:
# '/Users/rentaluser/Desktop/masterThesis/emotionCSV/pilotteam1round2.csv'

# %%
df = pd.read_csv(csvPath)

# %%
# find the P1 identified person data  / find the p2 idnetified dataset / find the p3 identified dataset 

p1 = df.loc[df['identified_person'] == "P1"] 
p2 = df.loc[df['identified_person'] == "P2"] 
p3 = df.loc[df['identified_person'] == "P3"] 

# indexing to help with data analysis in R section.
p1.index =range(len(p1['identified_person']))
p2.index =range(len(p2['identified_person']))
p3.index =range(len(p3['identified_person']))

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            2  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            4  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2            7  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           10  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           13  //Users/rentaluser/desktop/thesisVideo/videos/...
# 5           16  //Users/rentaluser/desktop/thesisVideo/videos/...
# 6           19  //Users/rentaluser/desktop/thesisVideo/videos/...
# 7           20  //Users/rentaluser/desktop/thesisVideo/videos/...
# 8           25  //Users/rentaluser/desktop/thesisVideo/videos/...
# 9           26  //Users/rentaluser/desktop/thesisVideo/videos/...
# 10          29  //Users/rentaluser/desktop/thesisVideo/videos/...
# 11          33  //Users/rentaluser/desktop/thesisVideo/videos/...
# 12          35  //Users/rentaluser/desktop/thesisVideo/videos/...
# 13          38  //Users/rentaluser/desktop/thesisVideo/videos/...
# 14          42  //Users/rentaluser/desktop/thesisVideo/videos/...
# 15          44  //Users/rentaluser/desktop/thesisVideo/videos/...
# 16          47  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0               0                P1                  99.997803        2
# 1               0                P1                  99.998299        2
# 2              17                P1                  99.997803        3
# 3              37                P1                  99.997803        3
# 4              57                P1                  99.997803        3
# 5              77                P1                  99.998299        3
# 6              97                P1                  99.997803        3
# 7             117                P1                  99.997803        1
# 8             137                P1                  99.997803        3
# 9             157                P1                  99.996201        1
# 10            177                P1                  99.998299        1
# 11            197                P1                  99.997803        2
# 12            217                P1                  99.997803        1
# 13            237                P1                  99.997803        1
# 14            257                P1                  99.997803        2
# 15            277                P1                  99.997803        1
# 16            297                P1                  99.998299        1
#
#     age_low  age_high  smile  eyeglasses  ...  eyesopen mouthopen   confused  \
# 0        19        31  False        True  ...      True     False   6.187886
# 1        18        30  False        True  ...      True     False   7.329999
# 2        20        32   True        True  ...      True      True   7.692313
# 3        22        34  False        True  ...      True      True   1.089437
# 4        20        32  False        True  ...      True     False   7.783760
# 5        20        32   True        True  ...      True     False   3.398890
# 6        18        30  False        True  ...      True     False   6.891224
# 7        12        22   True        True  ...      True      True   4.891994
# 8        21        33   True        True  ...      True      True   0.247142
# 9        22        34   True        True  ...      True      True   0.104500
# 10       20        32  False        True  ...      True     False   5.451904
# 11       22        34   True        True  ...      True      True   0.211148
# 12       22        34  False        True  ...      True     False   6.426547
# 13       22        34  False        True  ...      True     False  15.306902
# 14       22        34  False        True  ...      True     False   3.095016
# 15       22        34  False        True  ...      True      True   0.134207
# 16       19        31  False        True  ...      True     False  13.131740
#
#          calm      happy  disgusted     angry      fear        sad  surprised
# 0   82.108620   2.395950   2.127264  0.745905  0.404648   1.762389   4.267345
# 1   79.995911   2.276508   2.163928  0.788478  0.469241   1.897414   5.078531
# 2    5.604025  51.037407  16.766724  0.799520  1.246711   0.671236  16.182068
# 3    1.662676   1.771564   1.985364  0.322845  0.787199   0.268155  92.112755
# 4   74.989120   3.924090   4.380989  0.730503  0.667951   2.543125   4.980456
# 5   27.941502  59.687775   5.200070  0.431584  0.454820   1.256152   1.629213
# 6   86.726669   1.416767   1.590186  0.422556  0.153278   1.355933   1.443395
# 7    2.516767  32.923042  44.399132  4.508368  4.103680   2.222191   4.434829
# 8    0.049290  97.170387   1.064757  0.078595  0.166603   0.069433   1.153784
# 9    0.007358  99.339561   0.275903  0.085860  0.056391   0.039027   0.091391
# 10  80.833015   2.739775   3.505499  0.907915  0.424608   2.824424   3.312872
# 11   0.063828  99.383705   0.145482  0.036981  0.032823   0.034418   0.091620
# 12  64.824387   3.080099   6.544988  2.176670  0.973410  12.639552   3.334352
# 13  17.642746  10.332657  20.009111  2.987497  1.997915  30.081493   1.641683
# 14  83.342720   3.255032   2.968568  1.643323  0.298267   4.089345   1.307726
# 15   0.139198   1.288723   0.179520  0.279518  0.120423   0.014963  97.843452
# 16  42.217037   1.026250   2.783254  2.834184  0.483649  36.490837   1.033047
#
# [17 rows x 24 columns]

# %%
def emotions_col(pd) :
    pd['emotions'] =  (-1) *pd['confused'] + pd['calm'] + pd['happy'] - pd['disgusted'] + pd['angry'] - pd['fear'] + pd['sad'] + pd['surprised'] 
    return pd

# %%
""" Create a column that changes from ms to minutes  -> easier to look / view at the line graphs plot"""
def secs_to_min(pd): 
    pd['min_timestamp'] = pd['img_timestamp']/60 
    # change it to like minutes / seconds 
    # minutes and seconds 
    return pd

# %%
""" seconds to minutes upgraded version to figureo out how to match the graph """
def secs_to_upMins(pd): 
    # minutes and seconds 
    pd['min_upgrade'] = 0.0
    for i in range(len(pd['img_timestamp'])): 
        
        mins = int(pd.iloc[i]['img_timestamp']/60) 
        secs = pd.iloc[i]['img_timestamp']%60
        newmins = mins + secs/100
        pd.loc[i,'min_upgrade'] = newmins
    return pd

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            2  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            4  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2            7  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           10  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           13  //Users/rentaluser/desktop/thesisVideo/videos/...
# 5           16  //Users/rentaluser/desktop/thesisVideo/videos/...
# 6           19  //Users/rentaluser/desktop/thesisVideo/videos/...
# 7           20  //Users/rentaluser/desktop/thesisVideo/videos/...
# 8           25  //Users/rentaluser/desktop/thesisVideo/videos/...
# 9           26  //Users/rentaluser/desktop/thesisVideo/videos/...
# 10          29  //Users/rentaluser/desktop/thesisVideo/videos/...
# 11          33  //Users/rentaluser/desktop/thesisVideo/videos/...
# 12          35  //Users/rentaluser/desktop/thesisVideo/videos/...
# 13          38  //Users/rentaluser/desktop/thesisVideo/videos/...
# 14          42  //Users/rentaluser/desktop/thesisVideo/videos/...
# 15          44  //Users/rentaluser/desktop/thesisVideo/videos/...
# 16          47  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0               0                P1                  99.997803        2
# 1               0                P1                  99.998299        2
# 2              17                P1                  99.997803        3
# 3              37                P1                  99.997803        3
# 4              57                P1                  99.997803        3
# 5              77                P1                  99.998299        3
# 6              97                P1                  99.997803        3
# 7             117                P1                  99.997803        1
# 8             137                P1                  99.997803        3
# 9             157                P1                  99.996201        1
# 10            177                P1                  99.998299        1
# 11            197                P1                  99.997803        2
# 12            217                P1                  99.997803        1
# 13            237                P1                  99.997803        1
# 14            257                P1                  99.997803        2
# 15            277                P1                  99.997803        1
# 16            297                P1                  99.998299        1
#
#     age_low  age_high  smile  eyeglasses  ...       calm      happy  \
# 0        19        31  False        True  ...  82.108620   2.395950
# 1        18        30  False        True  ...  79.995911   2.276508
# 2        20        32   True        True  ...   5.604025  51.037407
# 3        22        34  False        True  ...   1.662676   1.771564
# 4        20        32  False        True  ...  74.989120   3.924090
# 5        20        32   True        True  ...  27.941502  59.687775
# 6        18        30  False        True  ...  86.726669   1.416767
# 7        12        22   True        True  ...   2.516767  32.923042
# 8        21        33   True        True  ...   0.049290  97.170387
# 9        22        34   True        True  ...   0.007358  99.339561
# 10       20        32  False        True  ...  80.833015   2.739775
# 11       22        34   True        True  ...   0.063828  99.383705
# 12       22        34  False        True  ...  64.824387   3.080099
# 13       22        34  False        True  ...  17.642746  10.332657
# 14       22        34  False        True  ...  83.342720   3.255032
# 15       22        34  False        True  ...   0.139198   1.288723
# 16       19        31  False        True  ...  42.217037   1.026250
#
#     disgusted     angry      fear        sad  surprised   emotions  \
# 0    2.127264  0.745905  0.404648   1.762389   4.267345  82.560412
# 1    2.163928  0.788478  0.469241   1.897414   5.078531  80.073674
# 2   16.766724  0.799520  1.246711   0.671236  16.182068  48.588508
# 3    1.985364  0.322845  0.787199   0.268155  92.112755  92.275995
# 4    4.380989  0.730503  0.667951   2.543125   4.980456  74.334595
# 5    5.200070  0.431584  0.454820   1.256152   1.629213  81.892446
# 6    1.590186  0.422556  0.153278   1.355933   1.443395  82.730631
# 7   44.399132  4.508368  4.103680   2.222191   4.434829  -6.789610
# 8    1.064757  0.078595  0.166603   0.069433   1.153784  97.042987
# 9    0.275903  0.085860  0.056391   0.039027   0.091391  99.126404
# 10   3.505499  0.907915  0.424608   2.824424   3.312872  81.235990
# 11   0.145482  0.036981  0.032823   0.034418   0.091620  99.221098
# 12   6.544988  2.176670  0.973410  12.639552   3.334352  72.110115
# 13  20.009111  2.987497  1.997915  30.081493   1.641683  25.372148
# 14   2.968568  1.643323  0.298267   4.089345   1.307726  87.276296
# 15   0.179520  0.279518  0.120423   0.014963  97.843452  99.131705
# 16   2.783254  2.834184  0.483649  36.490837   1.033047  67.202712
#
#     min_timestamp  min_upgrade
# 0        0.000000         0.00
# 1        0.000000         0.00
# 2        0.283333         0.17
# 3        0.616667         0.37
# 4        0.950000         0.57
# 5        1.283333         1.17
# 6        1.616667         1.37
# 7        1.950000         1.57
# 8        2.283333         2.17
# 9        2.616667         2.37
# 10       2.950000         2.57
# 11       3.283333         3.17
# 12       3.616667         3.37
# 13       3.950000         3.57
# 14       4.283333         4.17
# 15       4.616667         4.37
# 16       4.950000         4.57
#
# [17 rows x 27 columns]

# %%
""" main emotion and confidence level for each time line

calm	happy	disgusted	angry	fear	sad	surprised

""" 
def main_emotion(pd): 
    # main meotions 
    pd['main_emotion'] = 'emotion'
    pd['mainE_confidence'] = 0.0 
    for i in range(len(pd['img_timestamp'])): 
        # maximum of the values 
        max_e = max(pd.iloc[i]['calm'],pd.iloc[i]['happy'], pd.iloc[i]['disgusted'], pd.iloc[i]['angry'], 
                    pd.iloc[i]['fear'], pd.iloc[i]['sad'], pd.iloc[i]['surprised'])
        
        pd.loc[i, mainE_confidence] = max_e
        
        if max_e == pd.iloc[i]['calm']: 
            pd.loc[i, 'main_emotion'] = 'calm' 
        
        if max_e == pd.iloc[i]['happy']: 
            pd.loc[i, 'main_emotion'] = 'happy' 
        if max_e == pd.iloc[i]['disgusted']: 
            pd.loc[i, 'main_emotion'] = 'disgusted' 
        if max_e == pd.iloc[i]['angry']: 
            pd.loc[i, 'main_emotion'] = 'angry' 
        if max_e == pd.iloc[i]['fear']: 
            pd.loc[i, 'main_emotion'] = 'fear' 
        if max_e == pd.iloc[i]['sad']: 
            pd.loc[i, 'main_emotion'] = 'sad' 
        if max_e == pd.iloc[i]['surprised']: 
            pd.loc[i, 'main_emotion'] = 'surprised'
        
    return pd

# %%
p1 = emotions_col(p1)
p1 = secs_to_min(p1)
p1 = secs_to_upMins(p1)
p1 = main_emotion(p1)

p2 = emotions_col(p2)
p2 = secs_to_min(p2)
p2 = secs_to_upMins(p2)
p1 = main_emotion(p2)

p3 = emotions_col(p3)
p3= secs_to_min(p3)
p3 = secs_to_upMins(p3)


# change the indexing
# Out:
# <ipython-input-157-f722d05ca7ec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd['emotions'] =  (-1) *pd['confused'] + pd['calm'] + pd['happy'] - pd['disgusted'] + pd['angry'] - pd['fear'] + pd['sad'] + pd['surprised']
# <ipython-input-158-a6159e7b4334>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd['min_timestamp'] = pd['img_timestamp']/60
# <ipython-input-170-07802847f7c9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd['min_upgrade'] = 0.0
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            2  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            4  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2            7  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           10  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           13  //Users/rentaluser/desktop/thesisVideo/videos/...
# 5           16  //Users/rentaluser/desktop/thesisVideo/videos/...
# 6           19  //Users/rentaluser/desktop/thesisVideo/videos/...
# 7           20  //Users/rentaluser/desktop/thesisVideo/videos/...
# 8           25  //Users/rentaluser/desktop/thesisVideo/videos/...
# 9           26  //Users/rentaluser/desktop/thesisVideo/videos/...
# 10          29  //Users/rentaluser/desktop/thesisVideo/videos/...
# 11          33  //Users/rentaluser/desktop/thesisVideo/videos/...
# 12          35  //Users/rentaluser/desktop/thesisVideo/videos/...
# 13          38  //Users/rentaluser/desktop/thesisVideo/videos/...
# 14          42  //Users/rentaluser/desktop/thesisVideo/videos/...
# 15          44  //Users/rentaluser/desktop/thesisVideo/videos/...
# 16          47  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0               0                P1                  99.997803        2
# 1               0                P1                  99.998299        2
# 2              17                P1                  99.997803        3
# 3              37                P1                  99.997803        3
# 4              57                P1                  99.997803        3
# 5              77                P1                  99.998299        3
# 6              97                P1                  99.997803        3
# 7             117                P1                  99.997803        1
# 8             137                P1                  99.997803        3
# 9             157                P1                  99.996201        1
# 10            177                P1                  99.998299        1
# 11            197                P1                  99.997803        2
# 12            217                P1                  99.997803        1
# 13            237                P1                  99.997803        1
# 14            257                P1                  99.997803        2
# 15            277                P1                  99.997803        1
# 16            297                P1                  99.998299        1
#
#     age_low  age_high  smile  eyeglasses  ...       calm      happy  \
# 0        19        31  False        True  ...  82.108620   2.395950
# 1        18        30  False        True  ...  79.995911   2.276508
# 2        20        32   True        True  ...   5.604025  51.037407
# 3        22        34  False        True  ...   1.662676   1.771564
# 4        20        32  False        True  ...  74.989120   3.924090
# 5        20        32   True        True  ...  27.941502  59.687775
# 6        18        30  False        True  ...  86.726669   1.416767
# 7        12        22   True        True  ...   2.516767  32.923042
# 8        21        33   True        True  ...   0.049290  97.170387
# 9        22        34   True        True  ...   0.007358  99.339561
# 10       20        32  False        True  ...  80.833015   2.739775
# 11       22        34   True        True  ...   0.063828  99.383705
# 12       22        34  False        True  ...  64.824387   3.080099
# 13       22        34  False        True  ...  17.642746  10.332657
# 14       22        34  False        True  ...  83.342720   3.255032
# 15       22        34  False        True  ...   0.139198   1.288723
# 16       19        31  False        True  ...  42.217037   1.026250
#
#     disgusted     angry      fear        sad  surprised   emotions  \
# 0    2.127264  0.745905  0.404648   1.762389   4.267345  82.560412
# 1    2.163928  0.788478  0.469241   1.897414   5.078531  80.073674
# 2   16.766724  0.799520  1.246711   0.671236  16.182068  48.588508
# 3    1.985364  0.322845  0.787199   0.268155  92.112755  92.275995
# 4    4.380989  0.730503  0.667951   2.543125   4.980456  74.334595
# 5    5.200070  0.431584  0.454820   1.256152   1.629213  81.892446
# 6    1.590186  0.422556  0.153278   1.355933   1.443395  82.730631
# 7   44.399132  4.508368  4.103680   2.222191   4.434829  -6.789610
# 8    1.064757  0.078595  0.166603   0.069433   1.153784  97.042987
# 9    0.275903  0.085860  0.056391   0.039027   0.091391  99.126404
# 10   3.505499  0.907915  0.424608   2.824424   3.312872  81.235990
# 11   0.145482  0.036981  0.032823   0.034418   0.091620  99.221098
# 12   6.544988  2.176670  0.973410  12.639552   3.334352  72.110115
# 13  20.009111  2.987497  1.997915  30.081493   1.641683  25.372148
# 14   2.968568  1.643323  0.298267   4.089345   1.307726  87.276296
# 15   0.179520  0.279518  0.120423   0.014963  97.843452  99.131705
# 16   2.783254  2.834184  0.483649  36.490837   1.033047  67.202712
#
#     min_timestamp  min_upgrade
# 0        0.000000         0.00
# 1        0.000000         0.00
# 2        0.283333         0.17
# 3        0.616667         0.37
# 4        0.950000         0.57
# 5        1.283333         1.17
# 6        1.616667         1.37
# 7        1.950000         1.57
# 8        2.283333         2.17
# 9        2.616667         2.37
# 10       2.950000         2.57
# 11       3.283333         3.17
# 12       3.616667         3.37
# 13       3.950000         3.57
# 14       4.283333         4.17
# 15       4.616667         4.37
# 16       4.950000         4.57
#
# [17 rows x 27 columns]

# %%
# 3 different csv files for the creations at this point 
postProcessing = "/Users/rentaluser/Desktop/masterThesis/emotionCSV/processed/pilot_study"

p1.to_csv(postProcessing + "/pilotteam1r2_p1.csv") 
p2.to_csv(postProcessing + "/pilotteam1r2_p2.csv") 
p3.to_csv(postProcessing + "/pilotteam1r2_p3.csv")

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            2  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            4  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2            7  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           10  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           13  //Users/rentaluser/desktop/thesisVideo/videos/...
# 5           16  //Users/rentaluser/desktop/thesisVideo/videos/...
# 6           19  //Users/rentaluser/desktop/thesisVideo/videos/...
# 7           20  //Users/rentaluser/desktop/thesisVideo/videos/...
# 8           25  //Users/rentaluser/desktop/thesisVideo/videos/...
# 9           26  //Users/rentaluser/desktop/thesisVideo/videos/...
# 10          29  //Users/rentaluser/desktop/thesisVideo/videos/...
# 11          33  //Users/rentaluser/desktop/thesisVideo/videos/...
# 12          35  //Users/rentaluser/desktop/thesisVideo/videos/...
# 13          38  //Users/rentaluser/desktop/thesisVideo/videos/...
# 14          42  //Users/rentaluser/desktop/thesisVideo/videos/...
# 15          44  //Users/rentaluser/desktop/thesisVideo/videos/...
# 16          47  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0               0                P1                  99.997803        2
# 1               0                P1                  99.998299        2
# 2              17                P1                  99.997803        3
# 3              37                P1                  99.997803        3
# 4              57                P1                  99.997803        3
# 5              77                P1                  99.998299        3
# 6              97                P1                  99.997803        3
# 7             117                P1                  99.997803        1
# 8             137                P1                  99.997803        3
# 9             157                P1                  99.996201        1
# 10            177                P1                  99.998299        1
# 11            197                P1                  99.997803        2
# 12            217                P1                  99.997803        1
# 13            237                P1                  99.997803        1
# 14            257                P1                  99.997803        2
# 15            277                P1                  99.997803        1
# 16            297                P1                  99.998299        1
#
#     age_low  age_high  smile  eyeglasses  ...       calm      happy  \
# 0        19        31  False        True  ...  82.108620   2.395950
# 1        18        30  False        True  ...  79.995911   2.276508
# 2        20        32   True        True  ...   5.604025  51.037407
# 3        22        34  False        True  ...   1.662676   1.771564
# 4        20        32  False        True  ...  74.989120   3.924090
# 5        20        32   True        True  ...  27.941502  59.687775
# 6        18        30  False        True  ...  86.726669   1.416767
# 7        12        22   True        True  ...   2.516767  32.923042
# 8        21        33   True        True  ...   0.049290  97.170387
# 9        22        34   True        True  ...   0.007358  99.339561
# 10       20        32  False        True  ...  80.833015   2.739775
# 11       22        34   True        True  ...   0.063828  99.383705
# 12       22        34  False        True  ...  64.824387   3.080099
# 13       22        34  False        True  ...  17.642746  10.332657
# 14       22        34  False        True  ...  83.342720   3.255032
# 15       22        34  False        True  ...   0.139198   1.288723
# 16       19        31  False        True  ...  42.217037   1.026250
#
#     disgusted     angry      fear        sad  surprised   emotions  \
# 0    2.127264  0.745905  0.404648   1.762389   4.267345  82.560412
# 1    2.163928  0.788478  0.469241   1.897414   5.078531  80.073674
# 2   16.766724  0.799520  1.246711   0.671236  16.182068  48.588508
# 3    1.985364  0.322845  0.787199   0.268155  92.112755  92.275995
# 4    4.380989  0.730503  0.667951   2.543125   4.980456  74.334595
# 5    5.200070  0.431584  0.454820   1.256152   1.629213  81.892446
# 6    1.590186  0.422556  0.153278   1.355933   1.443395  82.730631
# 7   44.399132  4.508368  4.103680   2.222191   4.434829  -6.789610
# 8    1.064757  0.078595  0.166603   0.069433   1.153784  97.042987
# 9    0.275903  0.085860  0.056391   0.039027   0.091391  99.126404
# 10   3.505499  0.907915  0.424608   2.824424   3.312872  81.235990
# 11   0.145482  0.036981  0.032823   0.034418   0.091620  99.221098
# 12   6.544988  2.176670  0.973410  12.639552   3.334352  72.110115
# 13  20.009111  2.987497  1.997915  30.081493   1.641683  25.372148
# 14   2.968568  1.643323  0.298267   4.089345   1.307726  87.276296
# 15   0.179520  0.279518  0.120423   0.014963  97.843452  99.131705
# 16   2.783254  2.834184  0.483649  36.490837   1.033047  67.202712
#
#     min_timestamp  min_upgrade
# 0        0.000000         0.00
# 1        0.000000         0.00
# 2        0.283333         0.17
# 3        0.616667         0.37
# 4        0.950000         0.57
# 5        1.283333         1.17
# 6        1.616667         1.37
# 7        1.950000         1.57
# 8        2.283333         2.17
# 9        2.616667         2.37
# 10       2.950000         2.57
# 11       3.283333         3.17
# 12       3.616667         3.37
# 13       3.950000         3.57
# 14       4.283333         4.17
# 15       4.616667         4.37
# 16       4.950000         4.57
#
# [17 rows x 27 columns]
