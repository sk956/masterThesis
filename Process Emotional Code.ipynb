# %%
# checking again the code at this time 
import pandas as pd

# %%
 pwd = "/Users/rentaluser/Desktop/masterThesis/emotionCSV"

# %%
csvPath = pwd + "/pilotteam1round2Full.csv"

# %%
csvPath
# Out:
# '/Users/rentaluser/Desktop/masterThesis/emotionCSV/pilotteam1round2Full.csv'

# %%
df = pd.read_csv(csvPath)

# %%
# find the P1 identified person data  / find the p2 idnetified dataset / find the p3 identified dataset 

p1 = df.loc[df['identified_person'] == "P1"] 
p2 = df.loc[df['identified_person'] == "P2"] 
p3 = df.loc[df['identified_person'] == "P3"] 

# indexing to help with data analysis in R section.
p1.index =range(len(p1['identified_person']))
p2.index =range(len(p2['identified_person']))
p3.index =range(len(p3['identified_person']))

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            2  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            4  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2            6  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           10  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           13  //Users/rentaluser/desktop/thesisVideo/videos/...
# ..         ...                                                ...
# 95         286  //Users/rentaluser/desktop/thesisVideo/videos/...
# 96         289  //Users/rentaluser/desktop/thesisVideo/videos/...
# 97         292  //Users/rentaluser/desktop/thesisVideo/videos/...
# 98         295  //Users/rentaluser/desktop/thesisVideo/videos/...
# 99         298  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0               0                P1                  99.997803        2
# 1               0                P1                  99.998299        2
# 2              17                P1                  99.997803        2
# 3              37                P1                  99.997803        3
# 4              57                P1                  99.997803        3
# ..            ...               ...                        ...      ...
# 95           1877                P1                  99.997803        3
# 96           1897                P1                  99.997803        3
# 97           1917                P1                  99.997803        3
# 98           1937                P1                  99.997803        3
# 99           1957                P1                  99.996201        3
#
#     age_low  age_high  smile  eyeglasses  ...  eyesopen mouthopen   confused  \
# 0        19        31  False        True  ...      True     False   6.187886
# 1        18        30  False        True  ...      True     False   7.329999
# 2        22        34   True        True  ...      True      True   0.161228
# 3        21        33  False        True  ...      True     False  15.548287
# 4        22        34   True        True  ...      True      True   3.843402
# ..      ...       ...    ...         ...  ...       ...       ...        ...
# 95       19        31  False        True  ...      True     False  10.470432
# 96       22        34  False       False  ...      True      True   3.803100
# 97       22        34  False        True  ...      True      True   0.495844
# 98       21        33   True        True  ...      True     False   1.507121
# 99       22        34   True        True  ...      True     False   9.070044
#
#          calm      happy  disgusted      angry       fear       sad  surprised
# 0   82.108620   2.395950   2.127264   0.745905   0.404648  1.762389   4.267345
# 1   79.995911   2.276508   2.163928   0.788478   0.469241  1.897414   5.078531
# 2    0.030488  97.729431   1.142016   0.132019   0.102186  0.045894   0.656729
# 3   39.718689  20.082579  15.039820   1.090638   1.094261  3.319879   4.105852
# 4    4.521512   9.350216  29.187275   0.820585   0.830149  0.603263  50.843597
# ..        ...        ...        ...        ...        ...       ...        ...
# 95  75.712196   4.273638   2.620858   0.585344   0.352889  2.815979   3.168661
# 96   0.100720   0.053440   1.238669  90.868034   1.428405  0.776993   1.730633
# 97   1.112046   1.904631   2.379278   0.422757  65.460258  0.400167  27.825022
# 98   1.848682  91.055817   3.373835   0.194841   0.173971  0.335864   1.509877
# 99  13.210161  42.558243  26.804539   1.035601   1.072143  3.564832   2.684429
#
# [100 rows x 24 columns]

# %%
def emotions_col(pd) :
    pd['emotions'] =  (-1) *pd['confused'] + pd['calm'] + pd['happy'] - pd['disgusted'] + pd['angry'] - pd['fear'] + pd['sad'] + pd['surprised'] 
    
    return pd

# %%
# realized that the point graphs are cumulative 
def cum_emotions(pd): 
    pd['cum_emotions'] = 0.0
    for i in range(len(pd['emotions'])): 
        if i ==0 :
            pd.loc[i, 'cum_emotions'] = pd.iloc[i]['emotions']
        else: 
            pd.loc[i, 'cum_emotions'] = pd.iloc[i]['emotions'] +  pd.iloc[i-1]['cum_emotions']
        
    return pd

# %%
""" Create a column that changes from ms to minutes  -> easier to look / view at the line graphs plot"""
def secs_to_min(pd): 
    pd['min_timestamp'] = pd['img_timestamp']/60 
    # change it to like minutes / seconds 
    # minutes and seconds 
    return pd

# %%
""" seconds to minutes upgraded version to figureo out how to match the graph """
def secs_to_upMins(pd): 
    # minutes and seconds 
    pd['min_upgrade'] = 0.0
    for i in range(len(pd['img_timestamp'])): 
        
        mins = int(pd.iloc[i]['img_timestamp']/60) 
        secs = pd.iloc[i]['img_timestamp']%60
        newmins = mins + secs/100
        pd.loc[i,'min_upgrade'] = newmins
    return pd

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            2  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            4  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2            6  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           10  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           13  //Users/rentaluser/desktop/thesisVideo/videos/...
# ..         ...                                                ...
# 95         286  //Users/rentaluser/desktop/thesisVideo/videos/...
# 96         289  //Users/rentaluser/desktop/thesisVideo/videos/...
# 97         292  //Users/rentaluser/desktop/thesisVideo/videos/...
# 98         295  //Users/rentaluser/desktop/thesisVideo/videos/...
# 99         298  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0               0                P1                  99.997803        2
# 1               0                P1                  99.998299        2
# 2              17                P1                  99.997803        2
# 3              37                P1                  99.997803        3
# 4              57                P1                  99.997803        3
# ..            ...               ...                        ...      ...
# 95           1877                P1                  99.997803        3
# 96           1897                P1                  99.997803        3
# 97           1917                P1                  99.997803        3
# 98           1937                P1                  99.997803        3
# 99           1957                P1                  99.996201        3
#
#     age_low  age_high  smile  eyeglasses  ...  eyesopen mouthopen   confused  \
# 0        19        31  False        True  ...      True     False   6.187886
# 1        18        30  False        True  ...      True     False   7.329999
# 2        22        34   True        True  ...      True      True   0.161228
# 3        21        33  False        True  ...      True     False  15.548287
# 4        22        34   True        True  ...      True      True   3.843402
# ..      ...       ...    ...         ...  ...       ...       ...        ...
# 95       19        31  False        True  ...      True     False  10.470432
# 96       22        34  False       False  ...      True      True   3.803100
# 97       22        34  False        True  ...      True      True   0.495844
# 98       21        33   True        True  ...      True     False   1.507121
# 99       22        34   True        True  ...      True     False   9.070044
#
#          calm      happy  disgusted      angry       fear       sad  surprised
# 0   82.108620   2.395950   2.127264   0.745905   0.404648  1.762389   4.267345
# 1   79.995911   2.276508   2.163928   0.788478   0.469241  1.897414   5.078531
# 2    0.030488  97.729431   1.142016   0.132019   0.102186  0.045894   0.656729
# 3   39.718689  20.082579  15.039820   1.090638   1.094261  3.319879   4.105852
# 4    4.521512   9.350216  29.187275   0.820585   0.830149  0.603263  50.843597
# ..        ...        ...        ...        ...        ...       ...        ...
# 95  75.712196   4.273638   2.620858   0.585344   0.352889  2.815979   3.168661
# 96   0.100720   0.053440   1.238669  90.868034   1.428405  0.776993   1.730633
# 97   1.112046   1.904631   2.379278   0.422757  65.460258  0.400167  27.825022
# 98   1.848682  91.055817   3.373835   0.194841   0.173971  0.335864   1.509877
# 99  13.210161  42.558243  26.804539   1.035601   1.072143  3.564832   2.684429
#
# [100 rows x 24 columns]

# %%
""" main emotion and confidence level for each time line

calm	happy	disgusted	angry	fear	sad	surprised

""" 
def main_emotion(pd): 
    # main meotions 
    pd['main_emotion'] = 'emotion'
    pd['mainE_confidence'] = 0.0 
    for i in range(len(pd['img_timestamp'])): 
        # maximum of the values 
        max_e = max(pd.iloc[i]['calm'],pd.iloc[i]['happy'], pd.iloc[i]['disgusted'], pd.iloc[i]['angry'], 
                    pd.iloc[i]['fear'], pd.iloc[i]['sad'], pd.iloc[i]['surprised'])
        
        pd.loc[i, 'mainE_confidence'] = max_e
        
        if max_e == pd.iloc[i]['calm']: 
            pd.loc[i, 'main_emotion'] = 'calm' 
        
        if max_e == pd.iloc[i]['happy']: 
            pd.loc[i, 'main_emotion'] = 'happy' 
        if max_e == pd.iloc[i]['disgusted']: 
            pd.loc[i, 'main_emotion'] = 'disgusted' 
        if max_e == pd.iloc[i]['angry']: 
            pd.loc[i, 'main_emotion'] = 'angry' 
        if max_e == pd.iloc[i]['fear']: 
            pd.loc[i, 'main_emotion'] = 'fear' 
        if max_e == pd.iloc[i]['sad']: 
            pd.loc[i, 'main_emotion'] = 'sad' 
        if max_e == pd.iloc[i]['surprised']: 
            pd.loc[i, 'main_emotion'] = 'surprised'
        
    return pd

# %%
p1 = emotions_col(p1)
p1= cum_emotions(p1)
p1 = secs_to_min(p1)
p1 = secs_to_upMins(p1)
p1 = main_emotion(p1)

p2 = emotions_col(p2)
p2= cum_emotions(p2)
p2 = secs_to_min(p2)
p2 = secs_to_upMins(p2)
p2 = main_emotion(p2)

p3 = emotions_col(p3)
p3= cum_emotions(p3)
p3= secs_to_min(p3)
p3 = secs_to_upMins(p3)
p3 = main_emotion(p3)


# change the indexing
# Out:
# <ipython-input-268-f678d3d6162c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd['emotions'] =  (-1) *pd['confused'] + pd['calm'] + pd['happy'] - pd['disgusted'] + pd['angry'] - pd['fear'] + pd['sad'] + pd['surprised']
# <ipython-input-269-66d8c905fb2c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd['cum_emotions'] = 0.0
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# <ipython-input-271-07802847f7c9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd['min_upgrade'] = 0.0
# <ipython-input-273-78a2bcc23667>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd['main_emotion'] = 'emotion'
# <ipython-input-273-78a2bcc23667>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd['mainE_confidence'] = 0.0

# %%
p1
# Out:
#     Unnamed: 0                                           frame_id  \
# 0            2  //Users/rentaluser/desktop/thesisVideo/videos/...
# 1            4  //Users/rentaluser/desktop/thesisVideo/videos/...
# 2            6  //Users/rentaluser/desktop/thesisVideo/videos/...
# 3           10  //Users/rentaluser/desktop/thesisVideo/videos/...
# 4           13  //Users/rentaluser/desktop/thesisVideo/videos/...
# ..         ...                                                ...
# 95         286  //Users/rentaluser/desktop/thesisVideo/videos/...
# 96         289  //Users/rentaluser/desktop/thesisVideo/videos/...
# 97         292  //Users/rentaluser/desktop/thesisVideo/videos/...
# 98         295  //Users/rentaluser/desktop/thesisVideo/videos/...
# 99         298  //Users/rentaluser/desktop/thesisVideo/videos/...
#
#     img_timestamp identified_person  identification_confidence  face_id  \
# 0               0                P1                  99.997803        2
# 1               0                P1                  99.998299        2
# 2              17                P1                  99.997803        2
# 3              37                P1                  99.997803        3
# 4              57                P1                  99.997803        3
# ..            ...               ...                        ...      ...
# 95           1877                P1                  99.997803        3
# 96           1897                P1                  99.997803        3
# 97           1917                P1                  99.997803        3
# 98           1937                P1                  99.997803        3
# 99           1957                P1                  99.996201        3
#
#     age_low  age_high  smile  eyeglasses  ...      angry       fear       sad  \
# 0        19        31  False        True  ...   0.745905   0.404648  1.762389
# 1        18        30  False        True  ...   0.788478   0.469241  1.897414
# 2        22        34   True        True  ...   0.132019   0.102186  0.045894
# 3        21        33  False        True  ...   1.090638   1.094261  3.319879
# 4        22        34   True        True  ...   0.820585   0.830149  0.603263
# ..      ...       ...    ...         ...  ...        ...        ...       ...
# 95       19        31  False        True  ...   0.585344   0.352889  2.815979
# 96       22        34  False       False  ...  90.868034   1.428405  0.776993
# 97       22        34  False        True  ...   0.422757  65.460258  0.400167
# 98       21        33   True        True  ...   0.194841   0.173971  0.335864
# 99       22        34   True        True  ...   1.035601   1.072143  3.564832
#
#     surprised   emotions  cum_emotions  min_timestamp  min_upgrade  \
# 0    4.267345  82.560412     82.560412       0.000000         0.00
# 1    5.078531  80.073674    162.634086       0.000000         0.00
# 2    0.656729  97.189132    259.823217       0.283333         0.17
# 3    4.105852  36.635270    296.458487       0.616667         0.37
# 4   50.843597  32.278347    328.736834       0.950000         0.57
# ..        ...        ...           ...            ...          ...
# 95   3.168661  73.111640   6503.069783      31.283333        31.17
# 96   1.730633  87.059646   6590.129429      31.616667        31.37
# 97  27.825022 -36.670759   6553.458670      31.950000        31.57
# 98   1.509877  89.890153   6643.348823      32.283333        32.17
# 99   2.684429  26.106541   6669.455364      32.616667        32.37
#
#     main_emotion  mainE_confidence
# 0           calm         82.108620
# 1           calm         79.995911
# 2          happy         97.729431
# 3           calm         39.718689
# 4      surprised         50.843597
# ..           ...               ...
# 95          calm         75.712196
# 96         angry         90.868034
# 97          fear         65.460258
# 98         happy         91.055817
# 99         happy         42.558243
#
# [100 rows x 30 columns]

# %%
# 3 different csv files for the creations at this point 
postProcessing = "/Users/rentaluser/Desktop/masterThesis/emotionCSV/processed/pilot_study"

p1.to_csv(postProcessing + "/pilotteam1r2_Full_p1.csv") 
p2.to_csv(postProcessing + "/pilotteam1r2_Full_p2.csv") 
p3.to_csv(postProcessing + "/pilotteam1r2_Full_p3.csv")
